# %% [markdown]
# This script offers a preliminary evaluation of a variant of the motif graph learning algorithm that considers the observations follow a GMRF whose precision matrix is given by a polynomial of the GSO.

# %%
import cvxpy as cp
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

import time
from joblib import Parallel, delayed
from os import cpu_count

from sklearn.covariance import graphical_lasso
import src.utils as utils
import spectral_nti as snti

SEED = 0
N_CPUS = cpu_count()
np.random.seed(SEED)

PATH = './results/gmrf_st/'

# %% [markdown]
# ## Auxiliary functions

# %%
def est_graph(id, models, MM, L, K, iters, verb=False):
    X = utils.create_GMRF_st_signals(L, K, MM[-1])

    N = X.shape[0]
    A_hat = np.zeros((N, N, len(models), len(MM)))
    lamd_hat = np.zeros((N, len(models), len(MM)))
    for i, M in enumerate(MM):
        C_hat = X[:,:M]@X[:,:M].T/M

        # Individual standard constraints
        for j, model in enumerate(models):
            t = time.time()

            if model['name'] == 'GLasso':
                try:
                    _, L_hat = graphical_lasso(C_hat, model['alpha'], max_iter=iters)
                except FloatingPointError:
                    L_hat = np.zeros((N,N))
            elif model['St']:
                L_hat, _ = snti.MGL_Stationary_GMRF(C_hat, model['gs'], model['bounds'], 
                                                    model['cs'], model['regs'], max_iters=iters,
                                                    verbose=verb, epsilon=1e-5)
            else:
                L_hat, _ = snti.MGL(C_hat, model['gs'], model['bounds'], 
                                    model['cs'], model['regs'], max_iters=iters,
                                    verbose=verb, epsilon=1e-5)

            lamd_hat[:,j,i], _ = np.linalg.eigh(L_hat) 
            A_hat[:,:,j,i] = np.diag(np.diag(L_hat)) - L_hat
            t = time.time() - t
            print('Cov-{}, M-{}: Model: {}-{} - Time(sec): {:.3}'.format(id, M, model['name'],  model['St'], t))
    return A_hat, lamd_hat


def est_errs(A, lamd, A_hat, lams_hat, sq_err=True):
    norm_A = np.linalg.norm(A, 'fro')
    norm_lam = np.linalg.norm(lamd, 2)

    err_lamb = np.zeros(lams_hat.shape[1:])
    err_A = np.zeros(A_hat.shape[2:])
    for k in range(A_hat.shape[-1]):
        for i in range(A_hat.shape[-2]):
            for j in range(A_hat.shape[-3]):
                if np.all((A_hat[:,:,j,i,k] == 0)):
                    norm_A_hat = 1
                    norm_lam_hat = 1
                else:
                    norm_A_hat = np.linalg.norm(A_hat[:,:,j,i,k], 'fro')
                    norm_lam_hat = np.linalg.norm(lams_hat[:,j,i,k], 2)

                A_hat_norm = A_hat[:,:,j,i,k]/norm_A_hat
                lam_hat_norm = lams_hat[:,j,i,k]/norm_lam_hat
                err_A[j,i,k] = np.linalg.norm(A/norm_A-A_hat_norm,'fro')
                err_lamb[j,i,k] = np.linalg.norm(lamd/norm_lam-lam_hat_norm, 2)

                if sq_err:
                    err_A[j,i,k] = err_A[j,i,k]**2
                    err_lamb[j,i,k] = err_lamb[j,i,k]**2

    return err_A, err_lamb


def est_errs2(A, lamd, A_hat, lams_hat, sq_err=True):
    norm_A = np.linalg.norm(A, 'fro')
    norm_lam = np.linalg.norm(lamd, 2)

    err_lamb = np.zeros(lams_hat.shape[1:])
    err_A = np.zeros(A_hat.shape[2:])
    for k in range(A_hat.shape[-1]):
        for i in range(A_hat.shape[-2]):
            for j in range(A_hat.shape[-3]):
                if np.all((A_hat[:,:,j,i,k] == 0)):
                    norm_A_hat = 1
                    norm_lam_hat = 1
                else:
                    norm_A_hat = np.linalg.norm(A_hat[:,:,j,i,k], 'fro')
                    norm_lam_hat = np.linalg.norm(lams_hat[:,j,i,k], 2)

                err_A[j,i,k] = np.linalg.norm(A-A_hat[:,:,j,i,k],'fro')/norm_A
                err_lamb[j,i,k] = np.linalg.norm(lamd/-lams_hat[:,j,i,k], 2)/norm_lam

                if sq_err:
                    err_A[j,i,k] = err_A[j,i,k]**2
                    err_lamb[j,i,k] = err_lamb[j,i,k]**2

    return err_A, err_lamb


def plot_err(MM, models, err, ylab, semlogy=True, ylim=[]):
    plt.figure()
    for i, model in enumerate(models):
        if semlogy:
            plt.semilogy(MM, err[i,:], model['fmt'], label=model['name'],
                        linewidth=2, markersize=12)
        else:
            plt.plot(MM, err[i,:], model['fmt'], label=model['name'],
                     linewidth=2, markersize=12)
        plt.grid(True)
        plt.xlabel('Number of samples')
        plt.ylabel(ylab)
        plt.legend()
        plt.xlim([MM[0], MM[-1]])
        if ylim:
            plt.ylim(ylim)
        plt.tight_layout()


def print_err(MM, models, err):
    mean_err = np.mean(err, 2)
    std = np.std(err, 2)
    for i, M in enumerate(MM):
        print('M:', M)
        for j, model in enumerate(models):
            print('\t{}: mean err: {:.6f} - std: {:.6f}'.
                   format(model['name'], mean_err[j,i], std[j,i]))

# %% [markdown]
# ## Create graphs

# %%
# G params
k = 6
p = .25

# Ref graph
N0 = 50
A0 = nx.to_numpy_array(nx.watts_strogatz_graph(N0, k, p, seed=SEED))
L0 = np.diag(np.sum(A0, 0)) - A0
lambdas0, _ = np.linalg.eigh(L0)

# Target graph
N = 20
A = nx.to_numpy_array(nx.watts_strogatz_graph(N, k, p, seed=SEED))
L = np.diag(np.sum(A, 0)) - A
lambdas, V = np.linalg.eigh(L)
N = lambdas.shape[0]

norm_A = np.linalg.norm(A,'fro')
norm_lamb = np.linalg.norm(lambdas)

print('Norm of A:', norm_A)
print('Norm of lambdas:', norm_lamb)

# Plot graphs and spectrum distribution
plt.figure()
plt.subplot(1,2,1)
plt.imshow(A0)
plt.title('Ref A, N0: ' + str(N0))
plt.subplot(1,2,2)
plt.imshow(A)
plt.title('True A, N: ' + str(N))
    
figs, axs = plt.subplots(1, 2, sharey=True)
axs[0].hist(lambdas0, density=True)
axs[0].set_title('Ref Lambdas, N0: ' + str(N0))
axs[1].hist(lambdas, density=True)
axs[1].set_title('True Lambdas, N: ' + str(N))
# Out:
# Norm of A: 10.954451150103322
# Norm of lambdas: 29.325756597230356
# Text(0.5, 1.0, 'True Lambdas, N: 20')

# %%
M = 300
K = 4
X = utils.create_GMRF_st_signals(L, K, M)
C_st = X[:,:M]@X[:,:M].T/M

X = utils.create_signals(L, M)
C = X[:,:M]@X[:,:M].T/M

plt.figure()
plt.imshow(np.linalg.pinv(C_st))
plt.colorbar()

plt.figure()
plt.imshow(np.linalg.pinv(C))
plt.colorbar()

plt.figure()
plt.imshow(L)
plt.colorbar()

# %% [markdown]
# ## Compare contraints

# %%
n_covs = 10  #100
#MM = np.arange(300, 1501, 100)
MM = [100, 300, 500]
K = 4
iters = 30

GS = [
    lambda a, b : cp.sum(a)/b,
    lambda a, b : cp.sum(a**2)/b,
    lambda a, b : cp.sum(cp.exp(-a))/b,
    lambda a, b : cp.sum(cp.sqrt(a))/b,
    lambda a, b : cp.sum((.5*a-.75)**2)/b,
]
BOUNDS = [
    lambda lamd, lamd_t, b : -2/b*lamd_t.T@lamd,
    lambda lamd, lamd_t, b : 1/b*cp.exp(-lamd_t).T@lamd,
    lambda lamd, lamd_t, b : cp.sum(lamd/cp.sqrt(lamd_t))/(2*b),
    lambda lamd, lamd_t, b: 1/b*(0.75-.5*lamd_t).T@lamd,
]

# deltas = [.04, .27, .003, .02, 0.05]
deltas = [.001, .003, .015, .02, .03]
cs, err_cs = utils.compute_cs(GS, lambdas0, lambdas, verbose=True)

models = [
    {'St': False, 'name': 'GLasso', 'alpha': 0.05, 'fmt': '^:'},

    
    {'St': True, 'name': 'Unc', 'gs': [], 'bounds': [], 'cs': [], 'fmt': '1-',
     'regs': {'alpha': .01, 'beta': 1.75, 'gamma': 0, 'eta': 1, 'inc_eta': 1.1,
               'deltas': []}},
   
    {'St': True, 'name': 'Tr', 'gs': GS[0], 'bounds': [], 'cs': cs[0], 'fmt': '2-',
     'regs': {'alpha': 0, 'beta': 1, 'gamma': 1, 'eta': 1, 'inc_eta': 1.1,
              'deltas': deltas[0]}},

    {'St': True, 'name': 'Sq', 'gs': GS[1], 'bounds': BOUNDS[0], 'cs': cs[1], 'fmt': 'o-',
     'regs': {'alpha': .0, 'beta': 1.25, 'gamma': 500, 'eta': .05, 'inc_eta': 1.1,
              'deltas': deltas[1]}},

    {'St': True, 'name': 'BR', 'gs': GS[4], 'bounds': BOUNDS[3], 'cs': cs[4], 'fmt': 's-',
     'regs': {'alpha': 0, 'beta': 1, 'gamma': 10, 'eta': .1, 'inc_eta': 1.1, 
              'deltas': deltas[4]}},


    # Non-st
    {'St': False, 'name': 'Unc', 'gs': [], 'bounds': [], 'cs': [], 'fmt': '1--',
     'regs': {'alpha': .01, 'beta': 1.75, 'gamma': 0,'deltas': []}},


    {'St': False, 'name': 'Tr', 'gs': GS[0], 'bounds': [], 'cs': cs[0], 'fmt': '2--',
     'regs': {'alpha': 0, 'beta': 1, 'gamma': 1, 'deltas': deltas[0]}},

    {'St': False, 'name': 'Sq', 'gs': GS[1], 'bounds': BOUNDS[0], 'cs': cs[1], 'fmt': 'o--',
     'regs': {'alpha': .0, 'beta': 1.25, 'gamma': 500, 'deltas': deltas[1]}},
    


    # {'St': False, 'name': 'BR', 'gs': GS[4], 'bounds': BOUNDS[3], 'cs': cs[4], 'fmt': 's--',
    #  'regs': {'alpha': 0, 'beta': 1, 'gamma': 10, 'deltas': deltas[4]}},
]
# Out:
# 	c-0: c: 6.000	c0: 6.000	err: -0.000000	err norm: -0.000000
# 	c-1: c: 43.000	c0: 42.840	err: 0.160000	err norm: 0.003735
# 	c-2: c: 0.016	c0: 0.033	err: -0.016524	err norm: -0.504766
# 	c-3: c: 2.340	c0: 2.359	err: -0.018841	err norm: -0.007986
# 	c-4: c: 6.784	c0: 6.761	err: 0.023125	err norm: 0.003420

# %%
# Estimate graph
verbose = False

total_t = time.time()
As_hat = np.zeros((N, N, len(models), len(MM), n_covs))
lamds_hat = np.zeros((N, len(models), len(MM), n_covs)) 

print('N_CPUS:', N_CPUS)
pool = Parallel(n_jobs=N_CPUS, verbose=0)
resps = pool(delayed(est_graph)(i, models, MM, L, K, iters, verbose) for i in range(n_covs))
for i, resp in enumerate(resps):
    As_hat[:,:,:,:,i], lamds_hat[:,:,:,i] = resp

total_t = time.time() - total_t
print('-----', total_t/60, ' mins -----')
# Out:
# N_CPUS: 128
# Cov-0, M-100: Model: GLasso-False - Time(sec): 0.0193
# Cov-0, M-300: Model: GLasso-False - Time(sec): 0.00363
# Cov-5, M-100: Model: GLasso-False - Time(sec): 0.00504
# Cov-3, M-100: Model: GLasso-False - Time(sec): 0.00584
# Cov-5, M-300: Model: GLasso-False - Time(sec): 0.00375
# Cov-9, M-100: Model: GLasso-False - Time(sec): 0.00482
# Cov-7, M-100: Model: GLasso-False - Time(sec): 0.00389
# Cov-3, M-300: Model: GLasso-False - Time(sec): 0.00515
# Cov-1, M-100: Model: GLasso-False - Time(sec): 0.00382
# Cov-5, M-500: Model: GLasso-False - Time(sec): 0.00363
# Cov-2, M-100: Model: GLasso-False - Time(sec): 0.00483
# Cov-9, M-300: Model: GLasso-False - Time(sec): 0.00457
# Cov-7, M-300: Model: GLasso-False - Time(sec): 0.00471
# Cov-3, M-500: Model: GLasso-False - Time(sec): 0.00512
# Cov-9, M-500: Model: GLasso-False - Time(sec): 0.00471
# Cov-0, M-500: Model: GLasso-False - Time(sec): 0.0189
# Cov-2, M-300: Model: GLasso-False - Time(sec): 0.00562
# Cov-7, M-500: Model: GLasso-False - Time(sec): 0.00457
# Cov-6, M-100: Model: GLasso-False - Time(sec): 0.0061
# Cov-2, M-500: Model: GLasso-False - Time(sec): 0.00449
# Cov-6, M-300: Model: GLasso-False - Time(sec): 0.00562
# Cov-1, M-300: Model: GLasso-False - Time(sec): 0.0184
# Cov-6, M-500: Model: GLasso-False - Time(sec): 0.00574
# Cov-1, M-500: Model: GLasso-False - Time(sec): 0.0101
# Cov-8, M-100: Model: GLasso-False - Time(sec): 0.00494
# Cov-4, M-100: Model: GLasso-False - Time(sec): 0.00478
# Cov-8, M-300: Model: GLasso-False - Time(sec): 0.00555
# Cov-4, M-300: Model: GLasso-False - Time(sec): 0.00437
# Cov-4, M-500: Model: GLasso-False - Time(sec): 0.00437
# Cov-8, M-500: Model: GLasso-False - Time(sec): 0.00754
# ----- 0.019624348481496176  mins -----
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006118281215499621, tolerance: 0.005700714583365918
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006501837430157309, tolerance: 0.005822053990227472
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005859729495973909, tolerance: 0.005751966402245753
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010827232818009236, tolerance: 0.006035616038517055
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00852037602112432, tolerance: 0.005893950368941888
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0066427953194718725, tolerance: 0.005939153859514843
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00776571368805179, tolerance: 0.006174958485826499
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008079088594733719, tolerance: 0.0060133237163775225
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006964426455930095, tolerance: 0.006361596961270665
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006111763158138217, tolerance: 0.006046357018141842
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0182358375521261, tolerance: 0.0061195782210051375
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5002604613498391, tolerance: 0.006227637930459617
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5282051118670594, tolerance: 0.005928654977114758
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3797539225903606, tolerance: 0.005838805732323002
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.364395652994496, tolerance: 0.006060238804989676
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3133037205174247, tolerance: 0.005817205532963746
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008192000292197577, tolerance: 0.006027511170550636
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016025308385763992, tolerance: 0.005654355728557751
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022609033689576563, tolerance: 0.005740440747950801
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.024056228957221037, tolerance: 0.005700714583365918
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023709093832884776, tolerance: 0.005822053990227472
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02406453845947709, tolerance: 0.005751966402245753
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022682402927557632, tolerance: 0.006035616038517055
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01980642299267288, tolerance: 0.005893950368941888
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019679720788815303, tolerance: 0.005939153859514843
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015761018809108407, tolerance: 0.006174958485826499
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022354722417681216, tolerance: 0.0060133237163775225
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.027035761050562712, tolerance: 0.006361596961270665
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017448323416054734, tolerance: 0.006046357018141842
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012621180877552263, tolerance: 0.0061195782210051375
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2876573872304746, tolerance: 0.006227637930459617
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05748666794438151, tolerance: 0.005928654977114758
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007584083407081721, tolerance: 0.005778600892059863
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.0442938533136115, tolerance: 0.005838805732323002
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.582399354902165, tolerance: 0.006060238804989676
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0095597386097097, tolerance: 0.005817205532963746
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007860671170718092, tolerance: 0.006027511170550636
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01351600197376257, tolerance: 0.005654355728557751
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018928639850521733, tolerance: 0.005740440747950801
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013462340931361894, tolerance: 0.005700714583365918
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017319213518788956, tolerance: 0.005822053990227472
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01902677946920761, tolerance: 0.005751966402245753
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015393820322252338, tolerance: 0.006035616038517055
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009771114534544267, tolerance: 0.005893950368941888
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014991554152160802, tolerance: 0.005939153859514843
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012531949585159907, tolerance: 0.006174958485826499
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017552775123064634, tolerance: 0.0060133237163775225
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019753642241227, tolerance: 0.006361596961270665
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008044425784582643, tolerance: 0.006046357018141842
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007605171918385167, tolerance: 0.0061195782210051375
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.049622772369332324, tolerance: 0.006227637930459617
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09832652003614584, tolerance: 0.005928654977114758
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0076227910894672846, tolerance: 0.005778600892059863
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.017170084634408, tolerance: 0.005838805732323002
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.405811205913608, tolerance: 0.006060238804989676
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5046058510733644, tolerance: 0.005817205532963746
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005704926482650308, tolerance: 0.004385920803804148
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009041724453659583, tolerance: 0.004356009339839258
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005919577843705781, tolerance: 0.004339608006968197
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006667331352950612, tolerance: 0.004371797406042691
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007871788100672461, tolerance: 0.004370997213164219
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0072073979974760505, tolerance: 0.004416903548055657
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007295656056911071, tolerance: 0.004417687213979835
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06180284117466073, tolerance: 0.004423687254361218
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00830359844182027, tolerance: 0.004430098142628121
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009367372036820143, tolerance: 0.004521605546643033
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0045860682269847075, tolerance: 0.00454731472387882
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4976406793967456, tolerance: 0.004612050055883342
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.32152567420092737, tolerance: 0.0044984634430616606
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.347543759140251, tolerance: 0.00439367702393314
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2722605439448103, tolerance: 0.004403180091920516
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.042608009439551, tolerance: 0.004284734440628297
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007915996624781485, tolerance: 0.004494677817921497
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012494896002351652, tolerance: 0.004239618883134657
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020584161086084407, tolerance: 0.004385920803804148
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019408361533699292, tolerance: 0.004356009339839258
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022432882436731916, tolerance: 0.004339608006968197
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022494003511447147, tolerance: 0.004371797406042691
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020769676282114347, tolerance: 0.004370997213164219
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020439968850475054, tolerance: 0.004416903548055657
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014548531535034215, tolerance: 0.004417687213979835
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01975522598474555, tolerance: 0.004423687254361218
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020932759024866243, tolerance: 0.004430098142628121
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020069590245860525, tolerance: 0.004521605546643033
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01155042771505066, tolerance: 0.00454731472387882
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002093774421426886, tolerance: 0.0016993965114074062
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0073084018154361274, tolerance: 0.004517808844626451
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10402980602962231, tolerance: 0.004612050055883342
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10725583382694737, tolerance: 0.0044984634430616606
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005871556770404851, tolerance: 0.0017711057492406884
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2630640942473867, tolerance: 0.00439367702393314
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6932275056262469, tolerance: 0.004403180091920516
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008278363537286282, tolerance: 0.0017717321077758265
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.4580211619977064, tolerance: 0.004284734440628297
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001935703873435557, tolerance: 0.001832385026217596
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0073441743079527555, tolerance: 0.004494677817921497
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009326010626587333, tolerance: 0.004239618883134657
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008230534814654078, tolerance: 0.0018360123891442207
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01472284838219906, tolerance: 0.004385920803804148
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0033782523581642465, tolerance: 0.0017836435582701336
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012076378768284712, tolerance: 0.004356009339839258
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016426550007253127, tolerance: 0.004339608006968197
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016792786996632003, tolerance: 0.004371797406042691
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0023613590041922095, tolerance: 0.001674408416554104
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013882744956163151, tolerance: 0.004370997213164219
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011004343528156824, tolerance: 0.004416903548055657
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009607824473292226, tolerance: 0.0018916537684217404
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010960347441091756, tolerance: 0.004417687213979835
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0031604632904063124, tolerance: 0.0017660964588964846
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.21067258866955996, tolerance: 0.004423687254361218
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01815541684484856, tolerance: 0.004430098142628121
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0026448801927791976, tolerance: 0.0017431548565421569
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014233020131158014, tolerance: 0.004521605546643033
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006117117456064136, tolerance: 0.00454731472387882
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028878782313313422, tolerance: 0.0016993965114074062
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004860674958123923, tolerance: 0.004517808844626451
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0054325349582740046, tolerance: 0.004612050055883342
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016597885602989138, tolerance: 0.0016967367913689705
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009483329660312734, tolerance: 0.0044984634430616606
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10501542796151497, tolerance: 0.0017624650398826032
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2135175094913535, tolerance: 0.0017711057492406884
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.925197623925905, tolerance: 0.00439367702393314
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022320405400808596, tolerance: 0.0018351952556760294
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009715515642312766, tolerance: 0.004403180091920516
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22080089555931437, tolerance: 0.0017717321077758265
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016616454732222508, tolerance: 0.004284734440628297
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01844353215017236, tolerance: 0.0018427122844977284
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.057122730480331896, tolerance: 0.0018360123891442207
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008297691830527754, tolerance: 0.0017836435582701336
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005554534031560365, tolerance: 0.00451589881930575
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002356780541703074, tolerance: 0.001674408416554104
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008675962758076139, tolerance: 0.004504357608757782
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006065418680599066, tolerance: 0.004530230117320303
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00636355177233483, tolerance: 0.0018916537684217404
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006114052017942129, tolerance: 0.004564503457995461
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0054464735071277914, tolerance: 0.0017660964588964846
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008658962708388174, tolerance: 0.00454515444655746
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007188495551886831, tolerance: 0.0045820129983558605
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0030500049854431666, tolerance: 0.0017431548565421569
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007885592253579432, tolerance: 0.004597714960476462
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06414846021137777, tolerance: 0.004579143766771803
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007307175178624448, tolerance: 0.004597758117226363
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010085259856040807, tolerance: 0.004642745035098114
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3492976025204513, tolerance: 0.004728904491898572
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3541042143972035, tolerance: 0.004667481319791775
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011387054516710293, tolerance: 0.00443441877065349
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2710188161257037, tolerance: 0.004550258534329451
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00224966518386438, tolerance: 0.002187764975324822
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5502783312164325, tolerance: 0.004572531008236215
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# ...
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01385795588332428, tolerance: 0.0022174584012099323
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019525129431194443, tolerance: 0.0022295088577124153
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003951598981107196, tolerance: 0.0021627452980194912
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004783512013030844, tolerance: 0.00218612525998524
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03676725189930963, tolerance: 0.0021443161897852572
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009709247358614448, tolerance: 0.00215619064521632
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007540411754884957, tolerance: 0.0021763705786370406
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009453116328550948, tolerance: 0.00217728187745548
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004733973633509692, tolerance: 0.00219268591421716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01750601752045, tolerance: 0.0022087571389579064
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04777650901697683, tolerance: 0.0022219269795560096
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5700196369393566, tolerance: 0.002202037397314989
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0023991274053436484, tolerance: 0.0021926966187013103
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12556737694871956, tolerance: 0.002187366695054268
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004845696723489112, tolerance: 0.002173476687162716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004373504384194149, tolerance: 0.002221476574207765
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006863248190555282, tolerance: 0.0022039482872651577
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20588819619951337, tolerance: 0.0021986661252066777
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012541190599765883, tolerance: 0.0021966433331156478
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01278921627115892, tolerance: 0.0022174584012099323
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.045358183142301556, tolerance: 0.0022295088577124153
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004058908568410402, tolerance: 0.0021627452980194912
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0048070081636772954, tolerance: 0.00218612525998524
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0530884342403084, tolerance: 0.0021443161897852572
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00902942519198291, tolerance: 0.00215619064521632
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01616533586448199, tolerance: 0.0021763705786370406
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022584946774646397, tolerance: 0.00217728187745548
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005096622359655356, tolerance: 0.00219268591421716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0045094332400346104, tolerance: 0.0022087571389579064
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03372721897282105, tolerance: 0.0022219269795560096
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6183671335868333, tolerance: 0.002202037397314989
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0041726908011270325, tolerance: 0.0021926966187013103
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003487894432616656, tolerance: 0.002187366695054268
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.020459531229604977, tolerance: 0.002173476687162716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02130535308432968, tolerance: 0.0022039482872651577
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4940114936969202, tolerance: 0.0021986661252066777
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010771269020342089, tolerance: 0.0021966433331156478
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.012129931028290741, tolerance: 0.0022174584012099323
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.109318681495985, tolerance: 0.0022295088577124153
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0036574415064691834, tolerance: 0.0021627452980194912
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005158990968290311, tolerance: 0.00218612525998524
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05389248605422736, tolerance: 0.0021443161897852572
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006554593755414118, tolerance: 0.00215619064521632
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.033783158626363274, tolerance: 0.0021763705786370406
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025866871059967877, tolerance: 0.00217728187745548
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006279117806343493, tolerance: 0.00219268591421716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004221900212584728, tolerance: 0.0022087571389579064
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032058658380421434, tolerance: 0.0022219269795560096
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6201881656099228, tolerance: 0.002202037397314989
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005058764859736442, tolerance: 0.0021926966187013103
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# /home/srey/.local/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:244: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0079820887820361, tolerance: 0.002187366695054268
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(

# %%
# err_lamb = est_err(lamds_hat, lambdas)

err_A, err_lamd = est_errs(A, lambdas, As_hat, lamds_hat, sq_err=True)

mean_err_lam = np.mean(err_lamd, 2)
plot_err(MM, models, mean_err_lam, 'Mean err(Lambda,Lambda*)')
plt.savefig('tmp/err_lamb.png')

mean_err_A = np.mean(err_A, 2)
plot_err(MM, models, mean_err_A, 'Mean err(A,A*)')
plt.savefig('tmp/err_A.png')

mean_err_A = np.median(err_A, 2)
plot_err(MM, models, mean_err_A, 'Mean err(A,A*)')
plt.savefig('tmp/err_A_med.png')

# %%
err_A, err_lamd = est_errs2(A, lambdas, As_hat, lamds_hat, sq_err=True)

mean_err_lam = np.mean(err_lamd, 2)
plot_err(MM, models, mean_err_lam, 'Mean err(Lambda,Lambda*)')
plt.savefig('tmp/err_lamb2.png')

mean_err_A = np.mean(err_A, 2)
plot_err(MM, models, mean_err_A, 'Mean err(A,A*)')
plt.savefig('tmp/err_A2.png')

mean_err_A = np.median(err_A, 2)
plot_err(MM, models, mean_err_A, 'Mean err(A,A*)')
plt.savefig('tmp/err_A_med2.png')
# Out:
# /tmp/ipykernel_2231113/3113915484.py:81: RuntimeWarning: divide by zero encountered in divide
#   err_lamb[j,i,k] = np.linalg.norm(lamd/-lams_hat[:,j,i,k], 2)/norm_lam

# %%
# Save np data
# models_aux = [{'name': model['name'], 'fmt': model['fmt'], 'regs': model['regs']}
#                 for model in models]
# data = {
#     'A': A,
#     'lambdas': lambdas,
#     'lambdas0': lambdas0,
#     'As_hat': As_hat,
#     'lamds_hat': lamds_hat,
#     'MM': MM,
#     'models': models_aux
# }
# file = 'constraints_{}covs_{}iters'.format(n_covs, iters)
# np.save('results/constraints/' + file, data)

# # Save spectrum
# N = 200
# N0 = 150

# models_hist = [{'name': 'True spectrum'}] + models

# all_lambdas = np.concatenate((lambdas.reshape([N, 1]),
#                               np.squeeze(lamds_hat[:,:,idx,0])), axis=1)

# fname = PATH + 'constraints_hists.csv'
# utils.error_to_csv(fname, models_hist, [], all_lambdas)

# fname = PATH + 'constraints_hists_ref.csv'
# models_hist_ref = [{'name': 'Ref spectrum'}]
# utils.error_to_csv(fname, models_hist_ref, [], lambdas0.reshape([N0, 1]))

# %%
# Save data as csv
# fname = PATH + 'constraints.csv'
# utils.error_to_csv(fname, models, MM, mean_err_lam)

# %%
# %matplotlib qt

# # Load data
# file = 'results/constraints/constraints_100covs_200iters.npy'
# data = np.load(file, allow_pickle=True).item()
# models = data['models']

# A = data['A']
# lambdas = data['lambdas']
# lambdas0 = data['lambdas0']
# As_hat = data['As_hat']
# lamds_hat = data['lamds_hat']
# MM = data['MM']
# models = data['models']
